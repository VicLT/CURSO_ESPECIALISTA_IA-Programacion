# %% [markdown]
# # 20. La despensa del Python.

# %% [markdown]
# ##Listas

# %% [markdown]
# ### Manos en la masa 1!

# %% [markdown]
# Escribe un pequeño programa que defina la variable `primera_palabra`y asígnale la primera palabra de tu lista de palabras. Comprueba con los index para ver si realmente has entendido cómo funciona.

# %%
frase = "El nombre de Python se deriva de la serie de televisión Monty Python's Flying Circus."

palabras = frase.split()
print(palabras)

primera_palabra = palabras[0]
print(primera_palabra)
# Out:
# ['El', 'nombre', 'de', 'Python', 'se', 'deriva', 'de', 'la', 'serie', 'de', 'televisión', 'Monty', "Python's", 'Flying', 'Circus.']
# El

# %% [markdown]
# ###Manos en la masa 2!

# %% [markdown]
# Otra pequeña prueba. Intenta cambiar el título del segundo libro en nuestra colección 'buenas_lecturas' por el libro "Nanas de la cebolla".

# %%
buenas_lecturas = []
buenas_lecturas.append("El rayo que no cesa")
buenas_lecturas.append("Viento del pueblo")
print(buenas_lecturas)

buenas_lecturas[1] = "Nanas de la cebolla"
print(buenas_lecturas)
# Out:
# ['El rayo que no cesa', 'Viento del pueblo']
# ['El rayo que no cesa', 'Nanas de la cebolla']

# %% [markdown]
# ###Manos en la masa 3!

# %% [markdown]
# Define la variable `buenos_libros`como una lista completa vacia. Ahora añade algunos de tus libros favoritos (al menos tres) e imprime los últimos dos libros que has añadido.

# %%
buenos_libros = []
buenos_libros.append("libro1")
buenos_libros.append("libro2")
buenos_libros.append("libro3")
print(buenos_libros)

los_dos_ultimos_libros = buenos_libros[-2:]
los_dos_ultimos_libros2 = buenos_libros[1:]
print(los_dos_ultimos_libros)
print(los_dos_ultimos_libros2)
# Out:
# ['libro1', 'libro2', 'libro3']
# ['libro2', 'libro3']
# ['libro2', 'libro3']

# %% [markdown]
# ###Manos en la masa 4!

# %% [markdown]
# Sube la colección de
# ```
# poesia_miguel_hernandez = ["Perito en lunas", "Nanas de la cebolla",
#               "El rayo que no cesa", "Viento del Pueblo",
#               "Cancionero y romancero de ausencias", "Elegía", "El hombre acecha"]
# ```
#  y dales una puntuación. ¿Podrías imprimir la puntuación que le des al primer libro en la lista? (Puedes usar indexaciones)

# %%
lista_valorada = []
lista_valorada.append(["Perito en lunas", 8])
lista_valorada.append(["Nanas de la cebolla", 7])
lista_valorada.append(["Nanas de la cebolla", 9])
print(lista_valorada)

puntuacion_primer_libro = lista_valorada[0][1]
print(puntuacion_primer_libro)
# Out:
# [['Perito en lunas', 8], ['Nanas de la cebolla', 7], ['Nanas de la cebolla', 9]]
# 8

# %% [markdown]
# ###Manos en la masa 5!

# %% [markdown]
# Construye tu propio diccionario sobre la lista teatro_miguel_hernandez. Intenta imprimir la puntuación de uno de ellos.
# ```teatro_miguel_hernandez = ["Quién te ha visto y quién te ve y sombra de lo que eras","El torero más valiente","Los hijos de la piedra"]```
#
# Para ello primero creamos el diccionario igualando el nombre de del diccionario a las llaves `{}`. Después añadimos el nombre de la lista seguido de unos corchetes `[]`entre los que ponemos el título del libro y esto lo igualamos a la puntuación del libro.
# Para saber la puntuación del libro lo que hacemos es imprimir el nombre del diccionario seguido de los corchetes entre los que se encuentra el título del libro.

# %%
dict_teatro = {}
dict_teatro["Quién te ha visto y quién te ve y sombra de lo que eras"] = 9
dict_teatro["El torero más valiente"] = 8
dict_teatro["Los hijos de la piedra"] = 7

print(dict_teatro["El torero más valiente"])
# Out:
# 8

# %% [markdown]
# ----------
