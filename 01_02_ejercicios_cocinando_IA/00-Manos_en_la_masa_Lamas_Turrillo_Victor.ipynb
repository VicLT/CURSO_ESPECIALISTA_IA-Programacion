# %% [markdown]
# #Práctica_01

# %% [markdown]
# Esta es mi primera celda de texto y se formatea usando el lenguaje [Markdown](https://help.github.com/en/articles/getting-started-with-writing-and-formatting-on-github)

# %%
# Todo lo escrito después de un  `#` no será procesado por el entorno de ejecución.
# Esto es lo que llamamos un comentario.
a = 5  # Asigna el valor 5  a la variable a
b = 4  # Asigna el valor 4  a la variable  b
a * b  # Calcula el producto de la variable a por la variable b
# Out:
# 20

# %%
from IPython.display import IFrame
IFrame('https://www.elchapuzasinformatico.com/', width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.elchapuzasinformatico.com/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# @title
from IPython.display import YouTubeVideo
YouTubeVideo('7wN5WSCZBXI', width=600, height=400)
