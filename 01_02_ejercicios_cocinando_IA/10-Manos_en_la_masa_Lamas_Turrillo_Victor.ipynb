# %% [markdown]
# # 10. Los utensilios de la Cocina de Python

# %% [markdown]
# ### Manos en la masa 1!

# %% [markdown]
# En la siguiente celda de código, escribe un simple programa que calcule cuántos minutos hay en siete semanas.

# %%
minutos = 60
horas = 24
dias = 7
semanas = 7
total_minutos = minutos * horas * dias * semanas
print(f"En {semanas} semanas hay {total_minutos} minutos.")
# Out:
# En 7 semanas hay 70560 minutos.

# %% [markdown]
# ###Manos en la masa 3!

# %% [markdown]
# Ahora, si sabes cuántas letras tiene tu nombre puedes averiguar la última letra.

# %%
nombre = "Víctor"
ultima_letra = nombre[5]
print(f"La última letra de mi nombre es la '{ultima_letra}'.")
# Out:
# La última letra de mi nombre es la 'r'.

# %% [markdown]
# ###Manos en la masa 4!

# %% [markdown]
# ¿Puedes escribir un programa que defina la variable `penultima_letra` y asignarle la penúltima letra de tu nombre?

# %%
penultima_letra = nombre[-2]
print(f"La penúltima letra de mi nombre es la '{penultima_letra}'.")

penultima_letra = nombre[len(nombre)-2]
print(f"La penúltima letra de mi nombre es la '{penultima_letra}'.")
# Out:
# La penúltima letra de mi nombre es la 'o'.
# La penúltima letra de mi nombre es la 'o'.

# %% [markdown]
# ### Manos en la masa 5!

# %% [markdown]
# ¿Puedes definir la variable `letras_intermedias` y asignarle todas las letras de tu nombre menos las dos primeras y las dos últimas?

# %%
letras_intermedias = nombre[2:-2]
print(f"Las dos primeras y las dos últimas letras de mi nombre son: '{letras_intermedias}'.")
# Out:
# Las dos primeras y las dos últimas letras de mi nombre son: 'ct'.

# %% [markdown]
# ### Manos en la masa 6!

# %% [markdown]
# Dándote las palabras `murcielago' y 'ayuntamiento', ¿podrías escribir un código que concatene todas las letras de la primera palabra sin la primera y la última letra y todas las letras de la segunda palabra sin las dos primeras y las dos últimas letras usando solo slicing y concatenación?

# %%
palabra1 = "murciélago"
palabra2 = "ayuntamiento"
combinacion = palabra1[1:-1] + palabra2[2:-2]
print(f"La combinación de ambas palabras recortadas es: '{combinacion}'")
# Out:
# La combinación de ambas palabras recortadas es: 'urciélaguntamien'
